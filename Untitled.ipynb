# %% [markdown]
# # Sales Analysis

# %%
import pandas as pd
from urllib.request import urlretrieve
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\user\\AppData\\Roaming\\Python\\Python39\\Scripts\\Sales analysis'

# %%
os.listdir('.')
# Out:
# ['.ipynb_checkpoints', '.jovianrc', 'Untitled.ipynb']

# %%
os.makedirs('./files', exist_ok = False)

# %%
os.listdir('.')
# Out:
# ['.ipynb_checkpoints', '.jovianrc', 'files', 'Untitled.ipynb']

# %%
urlretrieve('https://github.com/KeithGalli/Pandas-Data-Science-Tasks/tree/master/SalesAnalysis/Sales_Data','./files' + '/file1.zip')
# Out:
# ('./files/file1.zip', <http.client.HTTPMessage at 0x21feeca5ee0>)

# %%
url_list = ['https://raw.githubusercontent.com/KeithGalli/Pandas-Data-Science-Tasks/master/SalesAnalysis/Sales_Data/Sales_April_2019.csv',
           'https://raw.githubusercontent.com/KeithGalli/Pandas-Data-Science-Tasks/master/SalesAnalysis/Sales_Data/Sales_August_2019.csv'
            ,'https://raw.githubusercontent.com/KeithGalli/Pandas-Data-Science-Tasks/master/SalesAnalysis/Sales_Data/Sales_December_2019.csv'
            , 'https://raw.githubusercontent.com/KeithGalli/Pandas-Data-Science-Tasks/master/SalesAnalysis/Sales_Data/Sales_February_2019.csv'
            , 'https://raw.githubusercontent.com/KeithGalli/Pandas-Data-Science-Tasks/master/SalesAnalysis/Sales_Data/Sales_January_2019.csv'
            , 'https://raw.githubusercontent.com/KeithGalli/Pandas-Data-Science-Tasks/master/SalesAnalysis/Sales_Data/Sales_July_2019.csv'
            , 'https://raw.githubusercontent.com/KeithGalli/Pandas-Data-Science-Tasks/master/SalesAnalysis/Sales_Data/Sales_June_2019.csv'
            ,  'https://raw.githubusercontent.com/KeithGalli/Pandas-Data-Science-Tasks/master/SalesAnalysis/Sales_Data/Sales_March_2019.csv'
            ,'https://raw.githubusercontent.com/KeithGalli/Pandas-Data-Science-Tasks/master/SalesAnalysis/Sales_Data/Sales_September_2019.csv'
            ,'https://raw.githubusercontent.com/KeithGalli/Pandas-Data-Science-Tasks/master/SalesAnalysis/Sales_Data/Sales_October_2019.csv'
            ,'https://raw.githubusercontent.com/KeithGalli/Pandas-Data-Science-Tasks/master/SalesAnalysis/Sales_Data/Sales_November_2019.csv'
            , 'https://raw.githubusercontent.com/KeithGalli/Pandas-Data-Science-Tasks/master/SalesAnalysis/Sales_Data/Sales_May_2019.csv'
           ]

# %%
stri = "https://raw.githubusercontent.com/KeithGalli/Pandas-Data-Science-Tasks/master/SalesAnalysis/Sales_Data/Sales_May_2019.csv"
li = stri.split("Sales_Data")
li
# Out:
# ['https://raw.githubusercontent.com/KeithGalli/Pandas-Data-Science-Tasks/master/SalesAnalysis/',
#  '/Sales_May_2019.csv']

# %% [markdown]
# # Loading all the csv files in the directory

# %%
for ele in url_list:
    li = ele.split("Sales_Data")
    urlretrieve(ele, './files' + li[1])

# %%
os.listdir('./files')
# Out:
# ['file1.zip',
#  'Sales_April_2019.csv',
#  'Sales_August_2019.csv',
#  'Sales_December_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_January_2019.csv',
#  'Sales_July_2019.csv',
#  'Sales_June_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_September_2019.csv']

# %%
os.remove("./files/file1.zip")

# %%
li = os.listdir('./files')

# %%
df = pd.read_csv('./files/Sales_April_2019.csv')

# %% [markdown]
# # Merge all the .csv files to create a single .csv file

# %%
# Create an empty dataframe
months_data = pd.DataFrame()
for ele in li:
    df = pd.read_csv('./files/' + ele)
    months_data = pd.concat([months_data,df])

# %%
months_data.head(100)
# Out:
#    Order ID                     Product Quantity Ordered Price Each  \
# 0    176558        USB-C Charging Cable                2      11.95
# 1       NaN                         NaN              NaN        NaN
# 2    176559  Bose SoundSport Headphones                1      99.99
# 3    176560                Google Phone                1        600
# 4    176560            Wired Headphones                1      11.99
# ..      ...                         ...              ...        ...
# 95   176648            27in FHD Monitor                1     149.99
# 96   176649        USB-C Charging Cable                1      11.95
# 97   176650    Lightning Charging Cable                1      14.95
# 98   176651                      iPhone                1        700
# 99   176652          LG Washing Machine                1      600.0
#
#         Order Date                      Purchase Address
# 0   04/19/19 08:46          917 1st St, Dallas, TX 75001
# ...

# %% [markdown]
# # Create the updated .csv file

# %%
months_data.to_csv('all_data.csv', index = False)

# %%
all_data = pd.read_csv('all_data.csv')

# %%
all_data["Order Date"] = all_data["Order Date"].astype(str)

# %% [markdown]
# ## 1. Best month for sales? Total revenue generated in that month?

# %%
all_data["Price Each"] = pd.to_numeric(all_data["Price Each"], errors='coerce')
# By setting errors=’coerce’, you’ll transform the non-numeric values into NaN.

# %%
all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'], errors = 'coerce')

# %%
all_data["total"] = all_data["Price Each"]*all_data['Quantity Ordered']

# %%
all_data
new_df = all_data.copy()
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable               2.0       11.95
# 1           NaN                         NaN               NaN         NaN
# 2        176559  Bose SoundSport Headphones               1.0       99.99
# 3        176560                Google Phone               1.0      600.00
# 4        176560            Wired Headphones               1.0       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)               3.0        2.99
# 186846   259354                      iPhone               1.0      700.00
# 186847   259355                      iPhone               1.0      700.00
# 186848   259356      34in Ultrawide Monitor               1.0      379.99
# 186849   259357        USB-C Charging Cable               1.0       11.95
#
#             Order Date                         Purchase Address   total
# ...

# %%
df1 = all_data.copy()
all_data["Order Date"]
# Out:
# 0         04/19/19 08:46
# 1                    nan
# 2         04/07/19 22:30
# 3         04/12/19 14:38
# 4         04/12/19 14:38
#                ...
# 186845    09/17/19 20:56
# 186846    09/01/19 16:00
# 186847    09/23/19 07:39
# 186848    09/19/19 17:30
# 186849    09/30/19 00:18
# Name: Order Date, Length: 186850, dtype: object

# %%
new = df1["Order Date"].str.split(" ", expand = True)
new
# Out:
#                0
# 0       04/19/19
# 2       04/07/19
# 3       04/12/19
# 4       04/12/19
# 5       04/30/19
# ...          ...
# 186845  09/17/19
# 186846  09/01/19
# 186847  09/23/19
# 186848  09/19/19
# 186849  09/30/19
#
# [185950 rows x 1 columns]

# %%
df1["Date"] = new[0]
# df1["Time"] = new[1]
df1
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#        Order Date                         Purchase Address   total      Date
# ...

# %%
df1 = df1.dropna(how = "any")

# %%
df1
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#        Order Date                         Purchase Address   total      Date
# ...

# %%
df1.drop(["Date"], axis = 1, inplace = True)

# %%
df1
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#        Order Date                         Purchase Address   total
# ...

# %%
df1["month"] = df1["Order Date"].str[0:2].astype('int')

# %%
df1
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#        Order Date                         Purchase Address   total  month
# ...

# %%
df1["day"] = df1["Order Date"].str[3:5].astype('int')

# %%
df1
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#        Order Date                         Purchase Address   total  month  day
# ...

# %%
df2= round(df1.groupby("month")[["total"]].sum(),2)

# %%
df3 = df2.copy()
df3
# Out:
#             total
# month
# 1      1822256.73
# 2      2202022.42
# 3      2807100.38
# 4      3390670.24
# 5      3152606.75
# 6      2577802.26
# 7      2647775.76
# 8      2244467.88
# 9      2097560.13
# 10     3736726.88
# 11     3199603.20
# 12     4613443.34

# %%
sum = df2["total"].sum()

# %%
df2["sales_per"] = round(df2["total"]/sum, 2)*100

# %%
df2
# Out:
#             total  sales_per
# month
# 12     4613443.34       13.0
# 10     3736726.88       11.0
# 4      3390670.24       10.0
# 11     3199603.20        9.0
# 5      3152606.75        9.0
# 3      2807100.38        8.0
# 7      2647775.76        8.0
# 6      2577802.26        7.0
# 8      2244467.88        7.0
# 2      2202022.42        6.0
# 9      2097560.13        6.0
# 1      1822256.73        5.0

# %% [markdown]
# ### From the above result we can infer that max amount of sales revenue generated at the end of the year

# %%
df1[(df1.month == 4) & (df1.day == 1)]
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 50       176603        USB-C Charging Cable                1      11.95
# 73       176626  Bose SoundSport Headphones                1      99.99
# 125      176677      34in Ultrawide Monitor                1     379.99
# 172      176722      27in 4K Gaming Monitor                1     389.99
# 194      176743      27in 4K Gaming Monitor                1     389.99
# ...         ...                         ...              ...        ...
# 112782   169191            27in FHD Monitor                1     149.99
# 118424   174575       AA Batteries (4-pack)                1       3.84
# 118825   174959  Bose SoundSport Headphones                1      99.99
# 119667   175769  Bose SoundSport Headphones                1      99.99
# 119858   175951                    LG Dryer                1        600
#
#        Order Date                         Purchase Address   total  month  day
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
months = range(1,13)
plt.bar(months, df3['total'])

plt.ylabel('Sales')
plt.xlabel('Month Number')
plt.show()

# %% [markdown]
# # What US city have the highest no of sales?

# %% [markdown]
# ### At first we have to create the city column

# %%
cities = df1["Purchase Address"].str.split(",", expand = True)

# %%
cities[1]
# Out:
# 0                 Dallas
# 2                 Boston
# 3            Los Angeles
# 4            Los Angeles
# 5            Los Angeles
#                ...
# 186845       Los Angeles
# 186846     San Francisco
# 186847     San Francisco
# 186848     San Francisco
# 186849     San Francisco
# Name: 1, Length: 185950, dtype: object

# %%
df4 = df1.copy()

# %%
df4
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#        Order Date                         Purchase Address   total  month  day
# ...

# %%
df4["cities"] = cities[1]

# %%
df4
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#        Order Date                         Purchase Address   total  month  \
# ...

# %% [markdown]
# ### Now we have to group by cities

# %%
cities_revenue = round(df4.groupby('cities')[['total']].sum(),2)

# %%
cities_revenue
# Out:
#                      total
# cities
#  Atlanta        2795498.58
#  Austin         1819581.75
#  Boston         3661642.01
#  Dallas         2767975.40
#  Los Angeles    5452570.80
#  New York City  4664317.43
#  Portland       2320490.61
#  San Francisco  8262203.91
#  Seattle        2747755.48

# %%
cities_revenue.index
# Out:
# Index([' Atlanta', ' Austin', ' Boston', ' Dallas', ' Los Angeles',
#        ' New York City', ' Portland', ' San Francisco', ' Seattle'],
#       dtype='object', name='cities')

# %%
plt.bar(cities_revenue.index,cities_revenue['total'])
# Out:
# <BarContainer object of 9 artists>

# %%
plt.pie(cities_revenue['total'],labels = cities_revenue.index )
plt.legend(loc='center left', bbox_to_anchor=(1.25, 0.5))
plt.show()

# %% [markdown]
# # Alternate way to find city column

# %%
new = new_df['Purchase Address'].str.split(',', expand = True)
new_df['city'] = new[1]
new_2 = new[2].str.split(" ",expand = True)
new_2
# Out:
#          0    1      2
# 0            TX  75001
# 1      NaN  NaN    NaN
# 2            MA  02215
# 3            CA  90001
# 4            CA  90001
# ...    ...  ...    ...
# 18378        CA  90001
# 18379        TX  73301
# 18380        CA  94016
# 18381        OR  97035
# 18382        MA  02215
#
# [18383 rows x 3 columns]

# %%
new_df['state'] = new_2[1]
new_df['postal_code'] = new_2[2]
new_df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address            city  \
# ...

# %%
new_df = new_df.dropna(how = 'any')
new_df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address            city  \
# ...

# %%
new_df['Order Date'] = pd.to_datetime(new_df['Order Date'])

# %%
new_df["hour"] = new_df["Order Date"].dt.hour

# %%
new_df["minute"] = new_df["Order Date"].dt.minute

# %%
final_df = (new_df.groupby('hour')[["Order ID"]].count()/18289)*100

# %%
plt.plot(final_df.index,final_df["Order ID"])
plt.xticks(final_df.index)
plt.xlabel('Hour')
plt.ylabel('Number of Orders')
plt.grid()
plt.show()

# %% [markdown]
# ### So from the baove graph we can say that there is max activity from 10 am to 9 pm
# ### And also there is a peak at 12pm and 7pm so the best time to post our ad will be around 11 am and 6 pm
# ### Thats how we can generate more leads
